# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
library(methods)
Snakemake <- setClass(
    "Snakemake",
    slots = c(
        input = "list",
        output = "list",
        params = "list",
        wildcards = "list",
        threads = "numeric",
        log = "list",
        resources = "list",
        config = "list",
        rule = "character",
        bench_iteration = "numeric",
        scriptdir = "character",
        source = "function"
    )
)
snakemake <- Snakemake(
    input = list(),
    output = list(),
    params = list(),
    wildcards = list(),
    threads = 1,
    log = list( 'rds' = 'out/ipynb/compute_unsupervised_classification/pca.rds'),
    resources = list('tmpdir', "tmpdir" = '/tmp'),
    config = list(),
    rule = 'ipynb',
    bench_iteration = as.numeric(NA),
    scriptdir = '/mnt/thymus/synoSalva/illumina_sequencing_data/mw/mw-oncodiag/src/snakemake/rules/../../ipynb',
    source = function(...){
        wd <- getwd()
        setwd(snakemake@scriptdir)
        source(...)
        setwd(wd)
    }
)
# setwd('/mnt/thymus/synoSalva/illumina_sequencing_data/mw/mw-oncodiag');
setwd('/srv/shiny-server/mw-oncodiag');

######## snakemake preamble end #########
context <- "CpG"
# context <- "CHH"
# context <- "CHG"

# %%
# start coding here

# %%
IRdisplay::display_markdown(
    sprintf(
"_Compute unsupervised classification %s_

__Oncodiag project__

[Guillaume Charbonnier](mailto:gc.bioinfo@gmail.com)

%s",
        snakemake@wildcards$design,
        format(Sys.Date(), "%Y-%m-%d")
    )
)

# %% [markdown]
# # Abstract
#
# The aim of this analysis is to assess the main components of variance in the dataset.

# %% [markdown]
# # Methods
#
# ## Load depencies
#
# ### Packages

# %%
if (!require("BiocManager", quietly = TRUE)) {
    install.packages(
        "BiocManager",
        quiet = TRUE
    )
}
packages <- c(
  # "data.table",
  # "dplyr",
  "openxlsx",
  # "methylSig",
  "DSS",
  "bsseq",
  "ChIPpeakAnno",
  "irlba",
  # "ChIPseeker",
  # "methyAnalysis",
  "org.Hs.eg.db",
  "TxDb.Hsapiens.UCSC.hg19.knownGene",
  # "EnhancedVolcano",
  # "data.table",
  "ggpubr",
  # "ComplexHeatmap",
  "tidyr"
)
BiocManager::install(
    packages,
    update = FALSE,
    quiet = TRUE,
    Ncpus = parallel::detectCores()
)
invisible(
    lapply(
      packages,
      library,
      character.only = TRUE
    )
)
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
# Bioconductor version 3.18 (BiocManager 1.30.22), R 4.3.2 (2023-10-31)
#
# Warning message:
# “package(s) not installed when version(s) same as or greater than current; use
#   `force = TRUE` to re-install: 'openxlsx' 'DSS' 'bsseq' 'ChIPpeakAnno' 'irlba'
#   'org.Hs.eg.db' 'TxDb.Hsapiens.UCSC.hg19.knownGene' 'ggpubr' 'tidyr'”
# Loading required package: Biobase
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: BiocParallel
#
# Loading required package: bsseq
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# The following object is masked from ‘package:Biobase’:
#
#     rowMedians
#
#
# Loading required package: parallel
#
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
# Loading required package: AnnotationDbi
#
#
#
# Loading required package: GenomicFeatures
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘tidyr’
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, pack, unpack
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand

# %%
sessionInfo()
# Out:
# R version 4.3.2 (2023-10-31)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Pop!_OS 22.04 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/gcharbonnier/mambaforge/envs/rkernel_diff_meth_v2/lib/libopenblasp-r0.3.24.so;  LAPACK version 3.11.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_DK.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_DK.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_DK.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_DK.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Paris
# tzcode source: system (glibc)
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] tidyr_1.3.0
#  [2] ggpubr_0.6.0
#  [3] ggplot2_3.4.4
#  [4] TxDb.Hsapiens.UCSC.hg19.knownGene_3.2.2
#  [5] GenomicFeatures_1.52.1
#  [6] org.Hs.eg.db_3.18.0
#  [7] AnnotationDbi_1.64.1
#  [8] irlba_2.3.5.1
#  [9] Matrix_1.6-1.1
# [10] ChIPpeakAnno_3.36.0
# [11] DSS_2.48.0
# [12] bsseq_1.38.0
# [13] SummarizedExperiment_1.30.2
# [14] MatrixGenerics_1.12.2
# [15] matrixStats_1.0.0
# [16] GenomicRanges_1.52.0
# [17] GenomeInfoDb_1.36.1
# [18] IRanges_2.34.1
# [19] S4Vectors_0.38.1
# [20] BiocParallel_1.34.2
# [21] Biobase_2.60.0
# [22] BiocGenerics_0.46.0
# [23] openxlsx_4.2.5.2
# [24] BiocManager_1.30.22
#
# loaded via a namespace (and not attached):
#   [1] jsonlite_1.8.7            magrittr_2.0.3
#   [3] BiocIO_1.10.0             zlibbioc_1.46.0
#   [5] vctrs_0.6.4               multtest_2.58.0
#   [7] memoise_2.0.1             Rsamtools_2.16.0
#   [9] DelayedMatrixStats_1.22.1 RCurl_1.98-1.13
#  [11] base64enc_0.1-3           rstatix_0.7.2
#  [13] htmltools_0.5.7           S4Arrays_1.0.4
#  [15] progress_1.2.2            lambda.r_1.2.4
#  [17] curl_5.1.0                broom_1.0.5
#  [19] Rhdf5lib_1.22.0           rhdf5_2.44.0
#  [21] futile.options_1.0.1      cachem_1.0.8
#  [23] uuid_1.1-1                GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.3           pkgconfig_2.0.3
#  [27] R6_2.5.1                  fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.10   digest_0.6.33
#  [31] colorspace_2.1-0          regioneR_1.34.0
#  [33] RSQLite_2.3.3             filelock_1.0.2
#  [35] fansi_1.0.5               abind_1.4-5
#  [37] httr_1.4.7                compiler_4.3.2
#  [39] withr_2.5.2               bit64_4.0.5
#  [41] backports_1.4.1           carData_3.0-5
#  [43] DBI_1.1.3                 HDF5Array_1.28.1
#  [45] R.utils_2.12.2            ggsignif_0.6.4
#  [47] biomaRt_2.56.1            MASS_7.3-60
#  [49] rappdirs_0.3.3            DelayedArray_0.26.6
#  [51] rjson_0.2.21              gtools_3.9.4
#  [53] permute_0.9-7             tools_4.3.2
#  [55] zip_2.3.0                 R.oo_1.25.0
#  [57] glue_1.6.2                VennDiagram_1.7.3
#  [59] restfulr_0.0.15           InteractionSet_1.30.0
#  [61] rhdf5filters_1.12.1       grid_4.3.2
#  [63] pbdZMQ_0.3-10             generics_0.1.3
#  [65] gtable_0.3.4              BSgenome_1.68.0
#  [67] R.methodsS3_1.8.2         data.table_1.14.8
#  [69] hms_1.1.3                 car_3.1-2
#  [71] xml2_1.3.5                utf8_1.2.4
#  [73] XVector_0.40.0            pillar_1.9.0
#  [75] stringr_1.5.0             IRdisplay_1.1
#  [77] limma_3.56.2              splines_4.3.2
#  [79] dplyr_1.1.3               BiocFileCache_2.8.0
#  [81] lattice_0.22-5            survival_3.5-7
#  [83] rtracklayer_1.60.0        bit_4.0.5
#  [85] tidyselect_1.2.0          RBGL_1.78.0
#  [87] locfit_1.5-9.8            Biostrings_2.68.1
#  [89] futile.logger_1.4.3       stringi_1.7.12
#  [91] yaml_2.3.7                evaluate_0.23
#  [93] codetools_0.2-19          tibble_3.2.1
#  [95] graph_1.80.0              cli_3.6.1
#  [97] IRkernel_1.3.2            repr_1.1.6
#  [99] munsell_0.5.0             Rcpp_1.0.11
# [101] dbplyr_2.4.0              png_0.1-8
# [103] XML_3.99-0.15             blob_1.2.4
# [105] prettyunits_1.2.0         sparseMatrixStats_1.12.2
# [107] bitops_1.0-7              scales_1.2.1
# [109] purrr_1.0.2               crayon_1.5.2
# [111] rlang_1.1.2               KEGGREST_1.40.0
# [113] formatR_1.14

# %%
set_plot_dim <- function(
    width = 16,
    height = 9
) {
    options(
        #jupyter.plot_scale=1,
        repr.plot.width = width,
        repr.plot.height = height
    )
}
set_plot_dim(5,5)

# %%
getwd()
# Out:
# [1] "/mnt/Data_2/mw-oncodiag"

# %% [markdown]
# ### Data

# %%
samples
# Out:
# new("standardGeneric", .Data = function (object)
# standardGeneric("samples"), generic = "samples", package = "Biobase",
#     group = list(), valueClass = character(0), signature = "object",
#     default = NULL, skeleton = (function (object)
#     stop(gettextf("invalid call in method dispatch to '%s' (no default method)",
#         "samples"), domain = NA))(object))
# <bytecode: 0x55bb931e3cb8>
# <environment: 0x55bb931e0650>
# attr(,"generic")
# [1] "samples"
# attr(,"generic")attr(,"package")
# [1] "Biobase"
# attr(,"package")
# [1] "Biobase"
# attr(,"group")
# list()
# attr(,"valueClass")
# character(0)
# attr(,"signature")
# [1] "object"
# attr(,"default")
# `\001NULL\001`
# attr(,"skeleton")
# (function (object)
# stop(gettextf("invalid call in method dispatch to '%s' (no default method)",
#     "samples"), domain = NA))(object)
# attr(,"class")
# [1] "standardGeneric"
# attr(,"class")attr(,"package")
# [1] "methods"

# %%
sample_metadata <- read.csv(
  "src/sample_sheets/all.csv"
)
# Here I temporarily subset the sample sheets to already available samples
suffix <- paste0(".markdup.sorted_", context, ".bedGraph")
# input_dir <- "out/nextflow/nfcore_methylseq/methyldackel/"
input_dir <- "out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/"

files <- list.files(
    path = input_dir,
    pattern = suffix
)
samples <- sub(
    suffix,
    "",
    files
)
sample_metadata <- sample_metadata[sample_metadata$sample %in% samples,]
# Remove patient 9 and 10 because they have low coverae
sample_metadata <- sample_metadata[!sample_metadata$patient_number %in% c(9,10),]
sample_metadata
# Out:
#    sample  fastq_1
# 1  ODG_080 inp/ONCODIAG/Novaseq_131222/fastq/ODG_080_S1_R1_001.fastq.gz
# 2  ODG_081 inp/ONCODIAG/Novaseq_131222/fastq/ODG_081_S2_R1_001.fastq.gz
# 3  ODG_082 inp/ONCODIAG/Novaseq_131222/fastq/ODG_082_S3_R1_001.fastq.gz
# 4  ODG_083 inp/ONCODIAG/Novaseq_131222/fastq/ODG_083_S4_R1_001.fastq.gz
# 5  ODG_084 inp/ONCODIAG/Novaseq_131222/fastq/ODG_084_S5_R1_001.fastq.gz
# 6  ODG_085 inp/ONCODIAG/Novaseq_131222/fastq/ODG_085_S6_R1_001.fastq.gz
# 7  ODG_086 inp/ONCODIAG/Novaseq_131222/fastq/ODG_086_S7_R1_001.fastq.gz
# 8  ODG_087 inp/ONCODIAG/Novaseq_131222/fastq/ODG_087_S8_R1_001.fastq.gz
# 9  ODG_088 inp/ONCODIAG/Novaseq_131222/fastq/ODG_088_S9_R1_001.fastq.gz
# 10 ODG_089 inp/ONCODIAG/Novaseq_131222/fastq/ODG_089_S10_R1_001.fastq.gz
# 11 ODG_090 inp/ONCODIAG/Novaseq_131222/fastq/ODG_090_S11_R1_001.fastq.gz
# 12 ODG_091 inp/ONCODIAG/Novaseq_131222/fastq/ODG_091_S12_R1_001.fastq.gz
# 13 ODG_092 inp/ONCODIAG/Novaseq_131222/fastq/ODG_092_S13_R1_001.fastq.gz
# 14 ODG_093 inp/ONCODIAG/Novaseq_131222/fastq/ODG_093_S14_R1_001.fastq.gz
# 15 ODG_094 inp/ONCODIAG/Novaseq_131222/fastq/ODG_094_S15_R1_001.fastq.gz
# 16 ODG_095 inp/ONCODIAG/Novaseq_131222/fastq/ODG_095_S16_R1_001.fastq.gz
# 21 ODG_100 inp/ONCODIAG/Novaseq_131222/fastq/ODG_100_S21_R1_001.fastq.gz
# 22 ODG_101 inp/ONCODIAG/Novaseq_131222/fastq/ODG_101_S22_R1_001.fastq.gz
# 23 ODG_102 inp/ONCODIAG/Novaseq_131222/fastq/ODG_102_S23_R1_001.fastq.gz
# 24 ODG_103 inp/ONCODIAG/Novaseq_131222/fastq/ODG_103_S24_R1_001.fastq.gz
# 25 ODG_104 inp/ONCODIAG/Novaseq_131222/fastq/ODG_104_S25_R1_001.fastq.gz
# 26 ODG_105 inp/ONCODIAG/Novaseq_131222/fastq/ODG_105_S26_R1_001.fastq.gz
# 27 ODG_106 inp/ONCODIAG/Novaseq_131222/fastq/ODG_106_S27_R1_001.fastq.gz
# 28 ODG_107 inp/ONCODIAG/Novaseq_131222/fastq/ODG_107_S28_R1_001.fastq.gz
# 29 ODG_108 inp/ONCODIAG/Novaseq_131222/fastq/ODG_108_S29_R1_001.fastq.gz
# 30 ODG_109 inp/ONCODIAG/Novaseq_131222/fastq/ODG_109_S30_R1_001.fastq.gz
#    fastq_2                                                       patient_number
# 1  inp/ONCODIAG/Novaseq_131222/fastq/ODG_080_S1_R2_001.fastq.gz   1
# 2  inp/ONCODIAG/Novaseq_131222/fastq/ODG_081_S2_R2_001.fastq.gz   1
# 3  inp/ONCODIAG/Novaseq_131222/fastq/ODG_082_S3_R2_001.fastq.gz   2
# 4  inp/ONCODIAG/Novaseq_131222/fastq/ODG_083_S4_R2_001.fastq.gz   2
# 5  inp/ONCODIAG/Novaseq_131222/fastq/ODG_084_S5_R2_001.fastq.gz   3
# 6  inp/ONCODIAG/Novaseq_131222/fastq/ODG_085_S6_R2_001.fastq.gz   3
# 7  inp/ONCODIAG/Novaseq_131222/fastq/ODG_086_S7_R2_001.fastq.gz   4
# 8  inp/ONCODIAG/Novaseq_131222/fastq/ODG_087_S8_R2_001.fastq.gz   4
# 9  inp/ONCODIAG/Novaseq_131222/fastq/ODG_088_S9_R2_001.fastq.gz   5
# 10 inp/ONCODIAG/Novaseq_131222/fastq/ODG_089_S10_R2_001.fastq.gz  5
# 11 inp/ONCODIAG/Novaseq_131222/fastq/ODG_090_S11_R2_001.fastq.gz  6
# 12 inp/ONCODIAG/Novaseq_131222/fastq/ODG_091_S12_R2_001.fastq.gz  6
# 13 inp/ONCODIAG/Novaseq_131222/fastq/ODG_092_S13_R2_001.fastq.gz  7
# 14 inp/ONCODIAG/Novaseq_131222/fastq/ODG_093_S14_R2_001.fastq.gz  7
# 15 inp/ONCODIAG/Novaseq_131222/fastq/ODG_094_S15_R2_001.fastq.gz  8
# 16 inp/ONCODIAG/Novaseq_131222/fastq/ODG_095_S16_R2_001.fastq.gz  8
# 21 inp/ONCODIAG/Novaseq_131222/fastq/ODG_100_S21_R2_001.fastq.gz 11
# 22 inp/ONCODIAG/Novaseq_131222/fastq/ODG_101_S22_R2_001.fastq.gz 11
# 23 inp/ONCODIAG/Novaseq_131222/fastq/ODG_102_S23_R2_001.fastq.gz 12
# 24 inp/ONCODIAG/Novaseq_131222/fastq/ODG_103_S24_R2_001.fastq.gz 12
# 25 inp/ONCODIAG/Novaseq_131222/fastq/ODG_104_S25_R2_001.fastq.gz 13
# 26 inp/ONCODIAG/Novaseq_131222/fastq/ODG_105_S26_R2_001.fastq.gz 13
# 27 inp/ONCODIAG/Novaseq_131222/fastq/ODG_106_S27_R2_001.fastq.gz 14
# 28 inp/ONCODIAG/Novaseq_131222/fastq/ODG_107_S28_R2_001.fastq.gz 14
# 29 inp/ONCODIAG/Novaseq_131222/fastq/ODG_108_S29_R2_001.fastq.gz 15
# 30 inp/ONCODIAG/Novaseq_131222/fastq/ODG_109_S30_R2_001.fastq.gz 15
#    tissue
# 1  normal
# 2  tumoral
# 3  normal
# 4  tumoral
# 5  normal
# 6  tumoral
# 7  normal
# 8  tumoral
# 9  normal
# 10 tumoral
# 11 normal
# 12 tumoral
# 13 normal
# 14 tumoral
# 15 normal
# 16 tumoral
# 21 normal
# 22 tumoral
# 23 normal
# 24 tumoral
# 25 normal
# 26 tumoral
# 27 normal
# 28 tumoral
# 29 normal
# 30 tumoral

# %%
# This will be used to load files with read.bismarck()
sample_metadata$bedGraph <- paste0(
    # 'out/nextflow/nfcore_methylseq/methyldackel/',
    # After 2023-11-06, I reprocessed methyldackel outside the nextflow pipeline
    # to have the possibility to generate CHH and CHG bedGraph files.
    'out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/',
    sample_metadata$sample,
    '.markdup.sorted_',
    context,
    '.bedGraph'
)

# %%
# row.names should be declared to be used as row.names of the BSseq object
# because DMLtest() uses these row.namesto select samples
row.names(sample_metadata) <- sample_metadata$sample
sample_metadata
# Out:
#         sample  fastq_1
# ODG_080 ODG_080 inp/ONCODIAG/Novaseq_131222/fastq/ODG_080_S1_R1_001.fastq.gz
# ODG_081 ODG_081 inp/ONCODIAG/Novaseq_131222/fastq/ODG_081_S2_R1_001.fastq.gz
# ODG_082 ODG_082 inp/ONCODIAG/Novaseq_131222/fastq/ODG_082_S3_R1_001.fastq.gz
# ODG_083 ODG_083 inp/ONCODIAG/Novaseq_131222/fastq/ODG_083_S4_R1_001.fastq.gz
# ODG_084 ODG_084 inp/ONCODIAG/Novaseq_131222/fastq/ODG_084_S5_R1_001.fastq.gz
# ODG_085 ODG_085 inp/ONCODIAG/Novaseq_131222/fastq/ODG_085_S6_R1_001.fastq.gz
# ODG_086 ODG_086 inp/ONCODIAG/Novaseq_131222/fastq/ODG_086_S7_R1_001.fastq.gz
# ODG_087 ODG_087 inp/ONCODIAG/Novaseq_131222/fastq/ODG_087_S8_R1_001.fastq.gz
# ODG_088 ODG_088 inp/ONCODIAG/Novaseq_131222/fastq/ODG_088_S9_R1_001.fastq.gz
# ODG_089 ODG_089 inp/ONCODIAG/Novaseq_131222/fastq/ODG_089_S10_R1_001.fastq.gz
# ODG_090 ODG_090 inp/ONCODIAG/Novaseq_131222/fastq/ODG_090_S11_R1_001.fastq.gz
# ODG_091 ODG_091 inp/ONCODIAG/Novaseq_131222/fastq/ODG_091_S12_R1_001.fastq.gz
# ODG_092 ODG_092 inp/ONCODIAG/Novaseq_131222/fastq/ODG_092_S13_R1_001.fastq.gz
# ODG_093 ODG_093 inp/ONCODIAG/Novaseq_131222/fastq/ODG_093_S14_R1_001.fastq.gz
# ODG_094 ODG_094 inp/ONCODIAG/Novaseq_131222/fastq/ODG_094_S15_R1_001.fastq.gz
# ODG_095 ODG_095 inp/ONCODIAG/Novaseq_131222/fastq/ODG_095_S16_R1_001.fastq.gz
# ODG_100 ODG_100 inp/ONCODIAG/Novaseq_131222/fastq/ODG_100_S21_R1_001.fastq.gz
# ODG_101 ODG_101 inp/ONCODIAG/Novaseq_131222/fastq/ODG_101_S22_R1_001.fastq.gz
# ODG_102 ODG_102 inp/ONCODIAG/Novaseq_131222/fastq/ODG_102_S23_R1_001.fastq.gz
# ODG_103 ODG_103 inp/ONCODIAG/Novaseq_131222/fastq/ODG_103_S24_R1_001.fastq.gz
# ODG_104 ODG_104 inp/ONCODIAG/Novaseq_131222/fastq/ODG_104_S25_R1_001.fastq.gz
# ODG_105 ODG_105 inp/ONCODIAG/Novaseq_131222/fastq/ODG_105_S26_R1_001.fastq.gz
# ODG_106 ODG_106 inp/ONCODIAG/Novaseq_131222/fastq/ODG_106_S27_R1_001.fastq.gz
# ODG_107 ODG_107 inp/ONCODIAG/Novaseq_131222/fastq/ODG_107_S28_R1_001.fastq.gz
# ODG_108 ODG_108 inp/ONCODIAG/Novaseq_131222/fastq/ODG_108_S29_R1_001.fastq.gz
# ODG_109 ODG_109 inp/ONCODIAG/Novaseq_131222/fastq/ODG_109_S30_R1_001.fastq.gz
#         fastq_2
# ODG_080 inp/ONCODIAG/Novaseq_131222/fastq/ODG_080_S1_R2_001.fastq.gz
# ODG_081 inp/ONCODIAG/Novaseq_131222/fastq/ODG_081_S2_R2_001.fastq.gz
# ODG_082 inp/ONCODIAG/Novaseq_131222/fastq/ODG_082_S3_R2_001.fastq.gz
# ODG_083 inp/ONCODIAG/Novaseq_131222/fastq/ODG_083_S4_R2_001.fastq.gz
# ODG_084 inp/ONCODIAG/Novaseq_131222/fastq/ODG_084_S5_R2_001.fastq.gz
# ODG_085 inp/ONCODIAG/Novaseq_131222/fastq/ODG_085_S6_R2_001.fastq.gz
# ODG_086 inp/ONCODIAG/Novaseq_131222/fastq/ODG_086_S7_R2_001.fastq.gz
# ODG_087 inp/ONCODIAG/Novaseq_131222/fastq/ODG_087_S8_R2_001.fastq.gz
# ODG_088 inp/ONCODIAG/Novaseq_131222/fastq/ODG_088_S9_R2_001.fastq.gz
# ODG_089 inp/ONCODIAG/Novaseq_131222/fastq/ODG_089_S10_R2_001.fastq.gz
# ODG_090 inp/ONCODIAG/Novaseq_131222/fastq/ODG_090_S11_R2_001.fastq.gz
# ODG_091 inp/ONCODIAG/Novaseq_131222/fastq/ODG_091_S12_R2_001.fastq.gz
# ODG_092 inp/ONCODIAG/Novaseq_131222/fastq/ODG_092_S13_R2_001.fastq.gz
# ODG_093 inp/ONCODIAG/Novaseq_131222/fastq/ODG_093_S14_R2_001.fastq.gz
# ODG_094 inp/ONCODIAG/Novaseq_131222/fastq/ODG_094_S15_R2_001.fastq.gz
# ODG_095 inp/ONCODIAG/Novaseq_131222/fastq/ODG_095_S16_R2_001.fastq.gz
# ODG_100 inp/ONCODIAG/Novaseq_131222/fastq/ODG_100_S21_R2_001.fastq.gz
# ODG_101 inp/ONCODIAG/Novaseq_131222/fastq/ODG_101_S22_R2_001.fastq.gz
# ODG_102 inp/ONCODIAG/Novaseq_131222/fastq/ODG_102_S23_R2_001.fastq.gz
# ODG_103 inp/ONCODIAG/Novaseq_131222/fastq/ODG_103_S24_R2_001.fastq.gz
# ODG_104 inp/ONCODIAG/Novaseq_131222/fastq/ODG_104_S25_R2_001.fastq.gz
# ODG_105 inp/ONCODIAG/Novaseq_131222/fastq/ODG_105_S26_R2_001.fastq.gz
# ODG_106 inp/ONCODIAG/Novaseq_131222/fastq/ODG_106_S27_R2_001.fastq.gz
# ODG_107 inp/ONCODIAG/Novaseq_131222/fastq/ODG_107_S28_R2_001.fastq.gz
# ODG_108 inp/ONCODIAG/Novaseq_131222/fastq/ODG_108_S29_R2_001.fastq.gz
# ODG_109 inp/ONCODIAG/Novaseq_131222/fastq/ODG_109_S30_R2_001.fastq.gz
#         patient_number tissue
# ODG_080  1             normal
# ODG_081  1             tumoral
# ODG_082  2             normal
# ODG_083  2             tumoral
# ODG_084  3             normal
# ODG_085  3             tumoral
# ODG_086  4             normal
# ODG_087  4             tumoral
# ODG_088  5             normal
# ODG_089  5             tumoral
# ODG_090  6             normal
# ODG_091  6             tumoral
# ODG_092  7             normal
# ODG_093  7             tumoral
# ODG_094  8             normal
# ODG_095  8             tumoral
# ODG_100 11             normal
# ODG_101 11             tumoral
# ODG_102 12             normal
# ODG_103 12             tumoral
# ODG_104 13             normal
# ODG_105 13             tumoral
# ODG_106 14             normal
# ODG_107 14             tumoral
# ODG_108 15             normal
# ODG_109 15             tumoral
#         bedGraph
# ODG_080 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_080.markdup.sorted_CpG.bedGraph
# ODG_081 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_081.markdup.sorted_CpG.bedGraph
# ODG_082 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_082.markdup.sorted_CpG.bedGraph
# ODG_083 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_083.markdup.sorted_CpG.bedGraph
# ODG_084 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_084.markdup.sorted_CpG.bedGraph
# ODG_085 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_085.markdup.sorted_CpG.bedGraph
# ODG_086 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_086.markdup.sorted_CpG.bedGraph
# ODG_087 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_087.markdup.sorted_CpG.bedGraph
# ODG_088 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_088.markdup.sorted_CpG.bedGraph
# ODG_089 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_089.markdup.sorted_CpG.bedGraph
# ODG_090 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_090.markdup.sorted_CpG.bedGraph
# ODG_091 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_091.markdup.sorted_CpG.bedGraph
# ODG_092 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_092.markdup.sorted_CpG.bedGraph
# ODG_093 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_093.markdup.sorted_CpG.bedGraph
# ODG_094 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_094.markdup.sorted_CpG.bedGraph
# ODG_095 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_095.markdup.sorted_CpG.bedGraph
# ODG_100 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_100.markdup.sorted_CpG.bedGraph
# ODG_101 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_101.markdup.sorted_CpG.bedGraph
# ODG_102 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_102.markdup.sorted_CpG.bedGraph
# ODG_103 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_103.markdup.sorted_CpG.bedGraph
# ODG_104 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_104.markdup.sorted_CpG.bedGraph
# ODG_105 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_105.markdup.sorted_CpG.bedGraph
# ODG_106 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_106.markdup.sorted_CpG.bedGraph
# ODG_107 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_107.markdup.sorted_CpG.bedGraph
# ODG_108 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_108.markdup.sorted_CpG.bedGraph
# ODG_109 out/methyldackel/extract_fa-genome-hg19/samtools/index/nextflow/nfcore_methylseq/bwameth/deduplicated/ODG_109.markdup.sorted_CpG.bedGraph

# %%
 snakemake@log$rds
# Out:
# [1] "out/ipynb/compute_unsupervised_classification/pca.rds"

# %%
hdf5a_dir <- paste0(
    "out/ipynb/compute_unsupervised_classification/",
    context,
    "_hdf5a"
)
hdf5a_file <- file.path(
    hdf5a_dir,
    "assays.h5"
)
# If the hdf5a dir exists, we can reload it directly
if (file.exists(hdf5a_file)) {
    bsseq_stranded <- HDF5Array::loadHDF5SummarizedExperiment(
        hdf5a_dir
    )
} else {
    # Defining loci first is more efficient
    loci <- findLoci(
        pattern = sub("p","", context),
        subject = "out/gunzip/to-stdout/wget/ftp/ftp.ensembl.org/pub/grch37/current/fasta/homo_sapiens/dna/Homo_sapiens.GRCh37.dna.toplevel.fasta",
        # subject = BSgenome.Hsapiens.UCSC.hg19,
        # include = seqlevels(subject),
        # strand = c("*", "+", "-"),
        strand = "*",
        # fixed = "subject",
        resize = TRUE
    )
    seqlevels(loci) <- sub(
        " dna.*$", "",
        seqlevels(loci)
    )

    bsseq_stranded <- bsseq::read.bismark(
        files = sample_metadata$bedGraph,
        loci = loci,
        colData = sample_metadata,
        # Trying to follow efficient use
        # https://rdrr.io/bioc/bsseq/man/read.bismark.html
        BPPARAM = MulticoreParam(workers = 2),
        nThread = 4,
        # rmZeroCov = TRUE,
        strandCollapse = TRUE,
        BACKEND = "HDF5Array",
        dir = hdf5a_dir,
        replace = TRUE
    )
}
bsseq_stranded
# Out:
# An object of type 'BSseq' with
#   55670825 methylation loci
#   26 samples
# has not been smoothed
# Some assays are HDF5Array-backed

# %%
mean_meth_by_sample <- colMeans(
    getMeth(
        bsseq_stranded,
        type="raw"
    ),
    na.rm = TRUE
)
mean_meth_by_sample
# Out:
#   ODG_080   ODG_081   ODG_082   ODG_083   ODG_084   ODG_085   ODG_086   ODG_087
# 0.7635777 0.7690022 0.7562209 0.6967489 0.7765936 0.7185696 0.7637274 0.7226603
#   ODG_088   ODG_089   ODG_090   ODG_091   ODG_092   ODG_093   ODG_094   ODG_095
# 0.7596708 0.7198710 0.7709615 0.7480050 0.7791672 0.7027933 0.7532199 0.7076699
#   ODG_100   ODG_101   ODG_102   ODG_103   ODG_104   ODG_105   ODG_106   ODG_107
# 0.7614409 0.7927854 0.7601589 0.7465821 0.7597913 0.7589644 0.7678219 0.7306411
#   ODG_108   ODG_109
# 0.7493335 0.6924195

# %%
df
# Out:
# function (x, df1, df2, ncp, log = FALSE)
# {
#     if (missing(ncp))
#         .Call(C_df, x, df1, df2, log)
#     else .Call(C_dnf, x, df1, df2, ncp, log)
# }
# <bytecode: 0x55bbcb7bb8f0>
# <environment: namespace:stats>

# %%
colData(bsseq_stranded)
# Out:
# DataFrame with 26 rows and 6 columns
#              sample                fastq_1                fastq_2
#         <character>            <character>            <character>
# ODG_080     ODG_080 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_081     ODG_081 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_082     ODG_082 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_083     ODG_083 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_084     ODG_084 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ...             ...                    ...                    ...
# ODG_105     ODG_105 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_106     ODG_106 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_107     ODG_107 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_108     ODG_108 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_109     ODG_109 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
#         patient_number      tissue               bedGraph
#              <integer> <character>            <character>
# ODG_080              1      normal out/methyldackel/ext..
# ODG_081              1     tumoral out/methyldackel/ext..
# ODG_082              2      normal out/methyldackel/ext..
# ODG_083              2     tumoral out/methyldackel/ext..
# ODG_084              3      normal out/methyldackel/ext..
# ...                ...         ...                    ...
# ODG_105             13     tumoral out/methyldackel/ext..
# ODG_106             14      normal out/methyldackel/ext..
# ODG_107             14     tumoral out/methyldackel/ext..
# ODG_108             15      normal out/methyldackel/ext..
# ODG_109             15     tumoral out/methyldackel/ext..

# %%
df <- data.frame(
    colData(bsseq_stranded)[, c("patient_number", "tissue")],
    mean_meth_by_sample
)
df$patient_number <- factor(df$patient_number)
ggplot(df, aes(x = patient_number, y = mean_meth_by_sample, fill = tissue)) +
  geom_bar(stat = "identity", position = "dodge") +
  xlab("Patient Number") +
  ylab("Mean methylation of loci") +
  scale_x_discrete(labels = function(x) vector("character", length(x))) + # Hide x-axis labels
#   ggtitle("Proportions of Methylation Values\nBelow 0.2 and Above 0.8") +
  theme_minimal()
# Out:
# plot without title

# %%
mean_cov <- rowMeans(getCoverage(bsseq_stranded))
quantile(mean_cov)
# Out:
#           0%          25%          50%          75%         100%
# 3.846154e-02 8.192308e+00 9.384615e+00 1.057692e+01 1.966796e+04

# %%
min_cov <- rowMins(getCoverage(bsseq_stranded))
quantile(min_cov)
# Out:
#   0%  25%  50%  75% 100%
#    0    1    2    3 6367

# %%
cg_sd <- rowSds(
    getMeth(
        bsseq_stranded,
        type="raw"
    ),
)
# Replace NA by 0 to remove them later with low sd sites
cg_sd[is.na(cg_sd)] <- 0
quantile(cg_sd)
# Out:
#          0%         25%         50%         75%        100%
# 0.000000000 0.005160951 0.092846065 0.173465783 0.509901951

# %%
mean_meth_by_sample <- colMeans(
    getMeth(
        bsseq_stranded[mean_cov > 10 & cg_sd > 0.2,],
        type="raw"
    ),
    na.rm = TRUE
)
mean_meth_by_sample
# Out:
#   ODG_080   ODG_081   ODG_082   ODG_083   ODG_084   ODG_085   ODG_086   ODG_087
# 0.5989497 0.6237493 0.5866787 0.5082282 0.6226175 0.5382645 0.6063189 0.5939118
#   ODG_088   ODG_089   ODG_090   ODG_091   ODG_092   ODG_093   ODG_094   ODG_095
# 0.6068903 0.5484054 0.6203349 0.6056863 0.6184217 0.5132998 0.5738349 0.5464812
#   ODG_100   ODG_101   ODG_102   ODG_103   ODG_104   ODG_105   ODG_106   ODG_107
# 0.5804569 0.7010795 0.5830298 0.6138595 0.5859879 0.6214608 0.5861355 0.5961843
#   ODG_108   ODG_109
# 0.5872336 0.5369021

# %%
df <- data.frame(
    colData(bsseq_stranded)[, c("patient_number", "tissue")],
    mean_meth_by_sample
)
df$patient_number <- factor(df$patient_number)
ggplot(df, aes(x = patient_number, y = mean_meth_by_sample, fill = tissue)) +
  geom_bar(stat = "identity", position = "dodge") +
  xlab("Patient Number") +
  ylab("Mean methylation of loci") +
#   ggtitle("Proportions of Methylation Values\nBelow 0.2 and Above 0.8") +
  theme_minimal()
# Out:
# plot without title

# %%
length(mean_cov)
length(cg_sd)
# Out:
# [1] 55670825
# [1] 55670825

# %%
n_low_coverage_sites_by_sample <-apply(
    as.matrix(getCoverage(bsseq_stranded)),
    2,
    FUN = function(x) {sum(x < 5)}
)
n_low_coverage_sites_by_sample[1:3]
# Out:
#  ODG_080  ODG_081  ODG_082
# 14511210  5181282  3599455

# %%
colData(bsseq_stranded)
# Out:
# DataFrame with 26 rows and 6 columns
#              sample                fastq_1                fastq_2
#         <character>            <character>            <character>
# ODG_080     ODG_080 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_081     ODG_081 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_082     ODG_082 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_083     ODG_083 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_084     ODG_084 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ...             ...                    ...                    ...
# ODG_105     ODG_105 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_106     ODG_106 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_107     ODG_107 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_108     ODG_108 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
# ODG_109     ODG_109 inp/ONCODIAG/Novaseq.. inp/ONCODIAG/Novaseq..
#         patient_number      tissue               bedGraph
#              <integer> <character>            <character>
# ODG_080              1      normal out/methyldackel/ext..
# ODG_081              1     tumoral out/methyldackel/ext..
# ODG_082              2      normal out/methyldackel/ext..
# ODG_083              2     tumoral out/methyldackel/ext..
# ODG_084              3      normal out/methyldackel/ext..
# ...                ...         ...                    ...
# ODG_105             13     tumoral out/methyldackel/ext..
# ODG_106             14      normal out/methyldackel/ext..
# ODG_107             14     tumoral out/methyldackel/ext..
# ODG_108             15      normal out/methyldackel/ext..
# ODG_109             15     tumoral out/methyldackel/ext..

# %%
df <- data.frame(
    colData(bsseq_stranded)[, c("patient_number", "tissue")],
    n_low_coverage_sites_by_sample
)
df$patient_number <- factor(df$patient_number)
ggplot(df, aes(x = patient_number, y = n_low_coverage_sites_by_sample, fill = tissue)) +
  geom_bar(stat = "identity", position = "dodge") +
  xlab("Patient Number") +
  ylab("Number of loci with coverage < 5 reads") +
#   ggtitle("Proportions of Methylation Values\nBelow 0.2 and Above 0.8") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Because of the high number of low coverage loci in patient 9 and 10, it is better to produce downstream plots without them.

# %%
# Subset for the sole purpose to have 
bsseq_subset <- bsseq_stranded[
    {
        mean_cov > 10 &
        # min_cov > 3 &
        cg_sd > 0.2
    },
    # We remove the patient 10 because it has very low coverage samples that bias the plots below
    !colData(bsseq_stranded)$patient_number %in% c(9,10)
]
bsseq_subset
# Out:
# An object of type 'BSseq' with
#   3896959 methylation loci
#   26 samples
# has not been smoothed
# Some assays are HDF5Array-backed

# %%
beta_values <- as.matrix(
        getMeth(
            bsseq_subset,
            type="raw"
        )
    )

# # Get coverage
# coverage <- as.matrix(getCoverage(bsseq_subset))

# # Define a threshold for low coverage
# threshold <- 10

# # Replace low coverage values with NA
# beta_values[coverage < threshold] <- NA

# beta_values[1:5,1:4]

# %%
pca_result <- prcomp_irlba(
    x = t(beta_values),
    n = 5,
    scale = FALSE
)

# %%
# Calculate the percentage of variance explained by each principal component
variance_explained <- pca_result$sdev^2 / sum(pca_result$sdev^2)

# Extract the first two principal components
pca_df <- data.frame(pca_result$x[,1:2])

# Name the columns
colnames(pca_df) <- c("PC1", "PC2")

# Create a combined data frame
combined_df <- cbind(pca_df, colData(bsseq_subset))
combined_df$patient_number <- factor(combined_df$patient_number)
# Create the plot
# Define a vector of shapes
shapes <- c(0:14, 21:25)

# Create the plot
ggplot(combined_df, aes(x=PC1, y=PC2, color=tissue, shape = patient_number)) +
  geom_point() +
  scale_shape_manual(values = shapes) +
  scale_color_manual(values = c("tumoral" = "red", "normal" = "blue")) +
  xlab(paste("First Principal Component: ", round(variance_explained[1] * 100, 2), "% variance")) +
  ylab(paste("Second Principal Component: ", round(variance_explained[2] * 100, 2), "% variance")) +
  ggtitle("PCA Plot") +
  theme_minimal() +
  labs(color = "Tissue", shape = "Patient Number")
# Out:
# plot without title

# %%
# Create the plot
p <- ggplot(combined_df, aes(x=PC1, y=PC2, color=tissue, group = patient_number)) +
  geom_point() +
  geom_line(aes(linetype = "patient"), color = "grey") + # Add linetype aesthetic
  scale_color_manual(values = c("tumoral" = "red", "normal" = "blue")) +
  scale_linetype_manual(values = c("patient" = "dotted"), name = "", labels = "Patient") + # Add custom legend
  xlab(paste("First Principal Component: ", round(variance_explained[1] * 100, 2), "% variance")) +
  ylab(paste("Second Principal Component: ", round(variance_explained[2] * 100, 2), "% variance")) +
  # ggtitle("PCA Plot") +
  theme_minimal() +
  labs(color = "Tissue")
p
ggsave(
  p,
  file = "PCA_for_article.pdf",
  width = 5,
  height = 5
)
# Out:
# plot without title

# %%
# Get the number of columns in the matrix
num_cols <- ncol(beta_values)

# Initialize vectors to store the proportions
prop_below_0_2 <- numeric(num_cols)
prop_above_0_8 <- numeric(num_cols)

# Calculate the proportions for each column
for (i in 1:num_cols) {
  prop_below_0_2[i] <- sum(beta_values[, i] < 0.2) / length(beta_values[, i])
  prop_above_0_8[i] <- sum(beta_values[, i] > 0.8) / length(beta_values[, i])
}

# Create a data frame for plotting
plot_df <- data.frame(Column = 1:num_cols, 
                      Below_0_2 = prop_below_0_2, 
                      Above_0_8 = prop_above_0_8)

# Reshape the data frame for plotting
library(reshape2)
plot_df_melt <- melt(plot_df, id.vars = "Column")
# Out:
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths

# %%
# Add patient_number to the data frame
plot_df$patient_number <- colData(bsseq_subset)$patient_number
plot_df$tissue <- colData(bsseq_subset)$tissue
plot_df$patient_number <- factor(plot_df$patient_number)
# Reshape the data frame for plotting
library(reshape2)
plot_df_melt <- melt(plot_df, id.vars = c("Column", "patient_number","tissue"))
# plot_df_melt
# Create the plot
library(ggplot2)
ggplot(plot_df_melt, aes(x = patient_number, y = value, fill = tissue)) +
  geom_bar(stat = "identity", position = "dodge") +
  facet_grid(variable~., scales = "free", labeller = as_labeller(c(Below_0_2 = "Below 0.2", Above_0_8 = "Above 0.8"))) +
  xlab("Patient Number") +
  ylab("Proportion of methylation values") +
  # ggtitle("Proportions of Methylation Values\nBelow 0.2 and Above 0.8") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# We remove the patient number for the article figure because they are irrelevant and would highlight the two low-quality patients that we removed from the analysis.

# %%
p <- ggplot(plot_df_melt, aes(x = patient_number, y = value, fill = tissue)) +
  geom_bar(stat = "identity", position = "dodge") +
  facet_grid(variable~., scales = "free", labeller = as_labeller(c(Below_0_2 = "Below 0.2", Above_0_8 = "Above 0.8"))) +
  scale_x_discrete(labels = function(x) vector("character", length(x))) + # Hide x-axis labels
  xlab("Patients") + # Change xlab to "Patients"
  ylab("Proportion of methylation values") +
  theme_minimal()
p
ggsave(
  p,
  file = "Barplots_for_article.pdf",
  width = 5,
  height = 5
)
# Out:
# plot without title

# %%
# Get the number of columns in the matrix
num_cols <- ncol(beta_values)

my_bw <- 0.05
# Calculate the density of the entire matrix
dens_all <- density(as.vector(beta_values), from = 0, to = 1, bw = my_bw)

# Plot the density of the entire matrix as a black line
plot(
    dens_all,
    xlim = c(0,1),
    ylim = c(0, 2.5),
    xlab = "Methylation level",
    ylab = "Density",
    main = "Overlayed distribution of methylation",
    xaxs = "i",
    col = "black"
)

# Loop over each column in the matrix
for (i in 1:num_cols) {
  # Get the density of the current column
  dens <- density(beta_values[, i], from = 0, to = 1, bw = my_bw)
  
  # Get the color for the current column based on 'Status'
  col <- ifelse(
    colData(bsseq_subset)$tissue[i] == "tumoral",
    "#ff000080",
    "#0000ff80"
  )
  
  # Add the density curve to the plot
  lines(dens, col = col)
}

# Add a legend
legend(
  "topleft", 
  legend = c("Tumoral", "Normal", "Median"),
  col = c("#ff000080", "#0000ff80", "black"),
  lty = 1,
  bty = "n"
)
# Out:
# Plot with title “Overlayed distribution of methylation”

# %%
# pdf("lineplots_for_article.pdf", width = 5, height = 5)
# Get the number of columns in the matrix
num_cols <- ncol(beta_values)

my_bw <- 0.05

# Loop over each column in the matrix
for (i in 1:num_cols) {
  # Get the density of the current column
  dens <- density(beta_values[, i], from = 0, to = 1, bw = my_bw)
  
  # Get the color for the current column based on 'Status'
  col <- ifelse(
    colData(bsseq_subset)$tissue[i] == "tumoral",
    "#ff000080",
    "#0000ff80"
  )
  
  # Add the density curve to the plot
  if(i == 1){
    plot(
      dens,
      xlim = c(0,1),
      ylim = c(0, 2.5),
      xlab = "Methylation level",
      ylab = "Density of occurences in loci",
      # main = "Overlayed distribution of methylation",
      main = NA,
      xaxs = "i",
      yaxs = "i",
      col = col
    )
  } else {
    lines(dens, col = col)
  }
}

# Add a legend
legend(
  "topleft", 
  legend = c("Tumoral", "Normal"),
  col = c("#ff000080", "#0000ff80"),
  lty = 1,
  bty = "n"
)
# dev.off()
# Out:
# Plot with title “NA”

# %% [markdown]
# We observe some artefactual peaks at intermediate values resulting from low coverage loci: 1/2, 2/3, 1,3, etc... We need to only consider loci-sample pairs with good coverage:

# %%
beta_value_high_cov <- beta_values
# Get coverage
coverage <- as.matrix(getCoverage(bsseq_subset))

# Define a threshold for low coverage
threshold <- 15

# Replace low coverage values with NA
beta_value_high_cov[coverage < threshold] <- NA

# Get the number of columns in the matrix
num_cols <- ncol(beta_value_high_cov)

# Calculate the density of the entire matrix
dens_all <- density(na.omit(as.vector(beta_value_high_cov)), from = 0, to = 1)

# Plot the density of the entire matrix as a black line
plot(
    dens_all,
    xlim = c(0,1),
    ylim = c(0, 5),
    xlab = "Methylation level",
    ylab = "Density",
    main = "Overlayed distribution of methylation",
    xaxs = "i",
    col = "black"
)

# Loop over each column in the matrix
for (i in 1:num_cols) {
  # Get the density of the current column
  dens <- density(na.omit(beta_value_high_cov[, i]), from = 0, to = 1)
  
  # Get the color for the current column based on 'Status'
  col <- ifelse(colData(bsseq_subset)$tissue[i] == "tumoral", "red", "blue")
  
  # Add the density curve to the plot
  lines(dens, col = col)
}

# Add a legend
legend(
  "topleft", 
  legend = c("Tumoral", "Normal", "Median"),
  col = c("red", "blue", "black"),
  lty = 1
)
# Out:
# Plot with title “Overlayed distribution of methylation”

# %%
sessionInfo()
# Out:
# R version 4.3.2 (2023-10-31)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Pop!_OS 22.04 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/gcharbonnier/mambaforge/envs/rkernel_diff_meth_v2/lib/libopenblasp-r0.3.24.so;  LAPACK version 3.11.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_DK.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_DK.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_DK.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_DK.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Paris
# tzcode source: system (glibc)
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] reshape2_1.4.4
#  [2] HDF5Array_1.28.1
#  [3] rhdf5_2.44.0
#  [4] DelayedArray_0.26.6
#  [5] S4Arrays_1.0.4
#  [6] tidyr_1.3.0
#  [7] ggpubr_0.6.0
#  [8] ggplot2_3.4.4
#  [9] TxDb.Hsapiens.UCSC.hg19.knownGene_3.2.2
# [10] GenomicFeatures_1.52.1
# [11] org.Hs.eg.db_3.18.0
# [12] AnnotationDbi_1.64.1
# [13] irlba_2.3.5.1
# [14] Matrix_1.6-1.1
# [15] ChIPpeakAnno_3.36.0
# [16] DSS_2.48.0
# [17] bsseq_1.38.0
# [18] SummarizedExperiment_1.30.2
# [19] MatrixGenerics_1.12.2
# [20] matrixStats_1.0.0
# [21] GenomicRanges_1.52.0
# [22] GenomeInfoDb_1.36.1
# [23] IRanges_2.34.1
# [24] S4Vectors_0.38.1
# [25] BiocParallel_1.34.2
# [26] Biobase_2.60.0
# [27] BiocGenerics_0.46.0
# [28] openxlsx_4.2.5.2
# [29] BiocManager_1.30.22
#
# loaded via a namespace (and not attached):
#   [1] jsonlite_1.8.7            magrittr_2.0.3
#   [3] farver_2.1.1              BiocIO_1.10.0
#   [5] zlibbioc_1.46.0           vctrs_0.6.4
#   [7] multtest_2.58.0           memoise_2.0.1
#   [9] Rsamtools_2.16.0          DelayedMatrixStats_1.22.1
#  [11] RCurl_1.98-1.13           base64enc_0.1-3
#  [13] rstatix_0.7.2             htmltools_0.5.7
#  [15] progress_1.2.2            lambda.r_1.2.4
#  [17] curl_5.1.0                broom_1.0.5
#  [19] Rhdf5lib_1.22.0           plyr_1.8.9
#  [21] futile.options_1.0.1      cachem_1.0.8
#  [23] uuid_1.1-1                GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.3           pkgconfig_2.0.3
#  [27] R6_2.5.1                  fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.10   digest_0.6.33
#  [31] colorspace_2.1-0          regioneR_1.34.0
#  [33] RSQLite_2.3.3             labeling_0.4.3
#  [35] filelock_1.0.2            fansi_1.0.5
#  [37] abind_1.4-5               httr_1.4.7
#  [39] compiler_4.3.2            withr_2.5.2
#  [41] bit64_4.0.5               backports_1.4.1
#  [43] carData_3.0-5             DBI_1.1.3
#  [45] R.utils_2.12.2            ggsignif_0.6.4
#  [47] biomaRt_2.56.1            MASS_7.3-60
#  [49] rappdirs_0.3.3            rjson_0.2.21
#  [51] gtools_3.9.4              permute_0.9-7
#  [53] tools_4.3.2               zip_2.3.0
#  [55] R.oo_1.25.0               glue_1.6.2
#  [57] VennDiagram_1.7.3         restfulr_0.0.15
#  [59] InteractionSet_1.30.0     rhdf5filters_1.12.1
#  [61] grid_4.3.2                pbdZMQ_0.3-10
#  [63] generics_0.1.3            gtable_0.3.4
#  [65] BSgenome_1.68.0           R.methodsS3_1.8.2
#  [67] data.table_1.14.8         hms_1.1.3
#  [69] car_3.1-2                 xml2_1.3.5
#  [71] utf8_1.2.4                XVector_0.40.0
#  [73] pillar_1.9.0              stringr_1.5.0
#  [75] IRdisplay_1.1             limma_3.56.2
#  [77] splines_4.3.2             dplyr_1.1.3
#  [79] BiocFileCache_2.8.0       lattice_0.22-5
#  [81] survival_3.5-7            rtracklayer_1.60.0
#  [83] bit_4.0.5                 tidyselect_1.2.0
#  [85] RBGL_1.78.0               locfit_1.5-9.8
#  [87] Biostrings_2.68.1         futile.logger_1.4.3
#  [89] stringi_1.7.12            yaml_2.3.7
#  [91] evaluate_0.23             codetools_0.2-19
#  [93] tibble_3.2.1              graph_1.80.0
#  [95] cli_3.6.1                 IRkernel_1.3.2
#  [97] repr_1.1.6                munsell_0.5.0
#  [99] Rcpp_1.0.11               dbplyr_2.4.0
# [101] png_0.1-8                 XML_3.99-0.15
# [103] blob_1.2.4                prettyunits_1.2.0
# [105] sparseMatrixStats_1.12.2  bitops_1.0-7
# [107] scales_1.2.1              purrr_1.0.2
# [109] crayon_1.5.2              rlang_1.1.2
# [111] KEGGREST_1.40.0           formatR_1.14
